# %%
# Import các thư viện cần dùng
# %matplotlib inline

import pandas as pd
import re
from pandas import DataFrame
import numpy as np
from matplotlib import pyplot as plt

import matplotlib
matplotlib.rcParams["figure.figsize"] = (20, 10)

# %%
# Đọc file dữ liệu flood_train.csv
#df1 = pd.read_csv('dataset/flood_train.csv')
df1 = pd.read_csv('file_resut.csv')
df1.head()
# Out:
#          datetime waterlevel
# 0  7/4/2013 21:30        NaN
# 1  7/4/2013 21:40        NaN
# 2  7/4/2013 21:50        27*
# 3  7/4/2013 22:00        28#
# 4  7/4/2013 22:10        28&

# %%
# Xem dữ liệu có bao nhiêu hàng bao nhiêu cột
df1.shape
# Out:
# (50317, 2)

# %%
# Xem có những cột gì
df1.columns
# Out:
# Index(['datetime', 'waterlevel'], dtype='object')

# %%
# Xem các giá trị của cột waterlevel
df1['waterlevel'].unique()
# Out:
# array([nan, '27*', '28#', '28&', '28!', '29#', '24', '25', '27', '29',
#        '3', '28', '31', '32', '33', '17', '18', '15', '16', '11', '1',
#        '13', '12', '14', '19', '2', '23', '22', '26', '35', '34', '37',
#        '36', '4', '41', '42', '45', '55', '57', '58', '59', '6', '61',
#        '62', '63', '65', '67', '68', '7', '71', '73', '74', '75', '77',
#        '76', '79', '8', '81', '82', '78', '83', '72', '84', '86', '87',
#        '88', '85', '69', '66', '64', '56', '53', '54', '49', '5', '47',
#        '48', '51', '52', '46', '44', '43', '39', '38', '21', '9', '89',
#        '91', '92', '93', '94', '95', '99', '1.01', '1.03', '1.07', '1.09',
#        '1.08', '1.11', '1.16', '1.17', '1.18', '1.21', '1.22', '1.24',
#        '1.25', '1.23', '1.27', '1.28', '1.26', '1.29', '1.3', '1.2',
#        '1.19', '1.14', '1.15', '1.13', '1.12', '1.1', '1.05', '1.06',
#        '1.02', '1.04', '97', '96', '98', '1.31', '1.32', '1.33', '1.34',
# ...

# %%
# Đếm số lượng giá trị của cột waterlevel
df1['waterlevel'].value_counts()
# Out:
# 28      921
# 38      773
# 39      766
# 37      760
# 26      748
#        ...
# 5.46      1
# 5.59      1
# 5.6       1
# 5.22      1
# 0         1
# Name: waterlevel, Length: 521, dtype: int64

# %%
# Xử lý loại bỏ các ký tự đặc biệt
df1['waterlevel'] = df1['waterlevel'].astype(str).str.replace(r'\W', '')

for i in df1['waterlevel']:
    if i == 'nan' or i == '':
        i = 0
    float(i)
print(df1['waterlevel'])
print(df1)
# Out:
# 0        nan
# 1        nan
# 2         27
# 3         28
# 4         28
#         ...
# 50312     57
# 50313     56
# 50314     56
# 50315     55
# 50316     54
# Name: waterlevel, Length: 50317, dtype: object
#               datetime waterlevel
# 0       7/4/2013 21:30        nan
# 1       7/4/2013 21:40        nan
# 2       7/4/2013 21:50         27
# 3       7/4/2013 22:00         28
# 4       7/4/2013 22:10         28
# ...                ...        ...
# 50312  6/30/2014 22:10         57
# 50313  6/30/2014 22:20         56
# 50314  6/30/2014 22:30         56
# 50315  6/30/2014 22:40         55
# 50316  6/30/2014 22:50         54
#
# [50317 rows x 2 columns]
# C:\Users\computer\AppData\Local\Temp\ipykernel_17372\1161937984.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['waterlevel'] = df1['waterlevel'].astype(str).str.replace(r'\W', '')

# %%
# Xử lý các giá trị null
# Đếm từng cột xem có bao nhiêu giá trị null
df1.isnull().sum()
# Gán giá trị null bằng giá trị trung bình của cột đó
df2 = df1.fillna(df1['waterlevel'].mean())
df2.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1626, in _ensure_numeric(x)
#    1625 try:
# -> 1626     x = complex(x)
#    1627 except ValueError as err:
#    1628     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df3 = DataFrame(df2, columns= ['datetime','waterlevel'])
# Đường dẫn, nơi lưu trữ tệp kết quả
export_csv = df3.to_csv(r'file_resut_2.csv', index = None, header=True)
print (df3)
# Out:
#               datetime waterlevel
# 0       7/4/2013 21:30        nan
# 1       7/4/2013 21:40        nan
# 2       7/4/2013 21:50        027
# 3       7/4/2013 22:00        028
# 4       7/4/2013 22:10        028
# ...                ...        ...
# 50312  6/30/2014 22:10        057
# 50313  6/30/2014 22:20        056
# 50314  6/30/2014 22:30        056
# 50315  6/30/2014 22:40        055
# 50316  6/30/2014 22:50        054
#
# [50317 rows x 2 columns]
